# %%
import os
paths = [
    r'C:/Users/prjap/Desktop/TecAI_task/test_api.bat',
    r'C:/Users/prjap/Desktop/TecAI_task/cart_test.bat',
    r'C:/Users/prjap/Desktop/TecAI_task/cart_test.js',
    r'C:/Users/prjap/Desktop/TecAI_task/product_test.js',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/api/authApi.js',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/context/AuthContext.jsx',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/routes/ProtectedRoutes.jsx',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/pages/Login.jsx',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/pages/Register.jsx',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/pages/Dashboard.jsx',
    r'C:/Users/prjap/Desktop/TecAI_task/frontend/src/App.css',
]
for p in paths:
    try:
        os.remove(p)
    except FileNotFoundError:
        pass
print('cleanup done')
